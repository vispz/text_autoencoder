# %%
# %matplotlib inline

# %%
from __future__ import division
from __future__ import unicode_literals

import logging
import os

import numpy as np
import pandas as pd
import torch as tc
import torch.utils.data as tc_data
import tqdm

import preprocessing
import model_utils as mu
import s2s_autoencoder as s2s
import tensorboard as tb

from pprint import pprint
from matplotlib import pyplot as plt
from IPython.display import display, HTML


plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize']= (10, 5)

pd.options.display.max_colwidth = 75
pd.options.display.width = 150
pd.options.display.max_columns = 40
css = open('/indocker/notebooks/style-table.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# is_cuda: True
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# </style>

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Setup logging

# %%
reload(logging)
log = logging.getLogger()
log.setLevel(logging.DEBUG)

myhandler = logging.StreamHandler()
myformatter = logging.Formatter(fmt='%(asctime)s:%(name)s:%(levelname)s: %(message)s')
myhandler.setFormatter(myformatter)
log.addHandler(myhandler)

# %% [markdown]
# **So we have around 4 million reviews**

# %% [markdown]
# ## Constants

# %%
REVIEW_FL = '/indocker/data/yelpds11/review.json'
W2V_FILE = '/indocker/data/glove.6B/glove.6B.50d-min.txt'
N_REVIEWS = 25000
MAX_LEN = 20
NUM_CPUS = 4

# %% [markdown]
# ## Load data

# %%
import codecs
import json
# Peek into the review data
with codecs.open(REVIEW_FL, encoding='utf-8') as infile:
    pprint(json.loads(infile.next()))
# Out:
# {u'business_id': u'0W4lkclzZThpx3V65bVgig',
#  u'cool': 0,
#  u'date': u'2016-05-28',
#  u'funny': 0,
#  u'review_id': u'v0i_UHJMo_hPBq9bxWvW4w',
#  u'stars': 5,
#  u'text': u"Love the staff, love the meat, love the place. Prepare for a long line around lunch or dinner hours. \n\nThey ask you how you want you meat, lean or something maybe, I can't remember. Just say you don't want it too fatty. \n\nGet a half sour pickle and a hot pepper. Hand cut french fries too.",
#  u'useful': 0,
#  u'user_id': u'bv2nCi5Qv5vroFiqKGopiw'}

# %%
w2v_data = preprocessing.load_w2v_data(path=W2V_FILE)
# Out:
# Loading embeddings: 100%|██████████| 9633/9633 [00:00<00:00, 69370.01it/s]

# %%
split_data = preprocessing.load_and_split_reviews(
    review_fl=REVIEW_FL,
    lang=w2v_data.lang,
    dev_frac=0.2,
    test_frac=0.2,
    n_reviews=N_REVIEWS,
    max_len=MAX_LEN,
    min_len=5,
)
split_data.train.head(2)
# Out:
# HBox(children=(IntProgress(value=0, description=u'Iter over reviews.: ', max=25000), HTML(value=u'')))
# HBox(children=(IntProgress(value=0, description=u'Iter over reviews.: ', max=25000), HTML(value=u'')))
#                 review_id  sent_num  sent_len                                                                         ixs  \
# 0  --vWmCoqCGZgcmsn7ELlUQ         0        20  [0, 55, 115, 8, 164, 395, 29, 3012, 947, 25, 1976, 5770, 113, 9, 4274, ...
# 1  --yQsDsWtziQMDSjmCMXrQ         0        20  [0, 39, 233, 175, 8, 32, 4, 3, 3, 112, 24, 13, 170, 3, 3, 8507, 934, 10...
#
#                                                                        tokens  \
# 0  [<SOS>, we, like, to, get, away, from, vegas, sometimes, by, visiting, ...
# 1  [<SOS>, this, place, used, to, be, the, notorious, p.i.g., now, it, 's,...
#
#                                                                          text
# 0  We like to get away from Vegas sometimes by visiting Boulder City and c...
# 1  This place used to be the Notorious P.I.G. now it 's called Hammered Ho...

# %%
split_data.train.sent_len.describe()
# Out:
# count    22250.000000
# mean        19.523506
# std          2.075740
# min          5.000000
# 25%         20.000000
# 50%         20.000000
# 75%         20.000000
# max         20.000000
# Name: sent_len, dtype: float64

# %% [markdown]
# ## Training

# %%
tb.clear_expts()
crayon_expt = tb.get_experiment(name='pytorch_ae')

# %% [markdown]
# ### Create model

# %%
s2s_ae = s2s.Seq2SeqAutoEncoder(
    lang=w2v_data.lang,
    config=s2s.Seq2SeqConfig(
        max_len=MAX_LEN,
        embed_dim=w2v_data.embedding_matrix.shape[1],
        hidden_dim=100,
        vocab_size=w2v_data.embedding_matrix.shape[0],
        bidirectional=True,
        num_layers=1,
        lr=0.001,
    ),
    embedding_matrix=w2v_data.embedding_matrix,
    verbose=True,
).cuda()
s2s_ae.share_memory()
# Out:
# Seq2SeqAutoEncoder(
#   (embedding): Embedding(9637, 50)
#   (encoder): EncoderRNN(
#     (embedding): Embedding(9637, 50)
#     (lstm): LSTM(50, 25, batch_first=True, bidirectional=True)
#   )
#   (decoder): DecoderRNN(
#     (embedding): Embedding(9637, 50)
#     (lstm): LSTM(100, 50, batch_first=True)
#     (vocab_softmax): Sequential(
#       (0): Linear(in_features=50, out_features=9637, bias=True)
#       (1): LogSoftmax()
#     )
#   )
#   (loss_fn): NLLLoss(
#   )
# )

# %% [markdown]
# ### Actually train

# %%
dataloader = mu.to_dataloader(
    train_sent_df=split_data.train[:10],
    dev_sent_df=split_data.dev[:10],
    batch_size=1024,
    num_workers=0,
    drop_last=True,
)

# %%
s2s.s2s_fit(
    s2s_model=s2s_ae,
    dataloader=dataloader,
    save_epoch_freq=1,
    model_save_path='s2s_2.pkl',
    epochs=10,
    teacher_forcing=0.5,
    tb_expt=crayon_expt,
)
# Out:
# HBox(children=(IntProgress(value=0, description=u'Epochs: ', max=10), HTML(value=u'')))
# HBox(children=(IntProgress(value=0, description=u'Batches: ', max=1), HTML(value=u'')))
# 2018-03-17 02:19:24,084:s2s_autoencoder:INFO:
#
# ---------------------------------------------------------------------
#
# EPOCH RESULT: 0
# =================
#
# dev/loss: 62.2697
# grad_by_wts/mean: 0.0496
# train/loss: 62.7797
# dev/evaluation/compute_accuracy: 0.0526
# grad_by_wts/std: 12.4597
# train/evaluation/compute_accuracy: 0.0474
#
# ---------------------------------------------------------------------
#
#
# 2018-03-17 02:19:24,085:s2s_autoencoder:INFO: Saving model to `s2s_2.pkl`...
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-77-1cdcab62aab6> in <module>()
#       6     epochs=10,
#       7     teacher_forcing=0.5,
# ----> 8     tb_expt=crayon_expt,
#       9 )
#
# /indocker/src/s2s_autoencoder.py in s2s_fit(s2s_model, dataloader, save_epoch_freq, model_save_path, epochs, teacher_forcing, tb_expt)
#     305         if save_epoch_freq and epoch_num % save_epoch_freq == 0:
#     306             log.info('Saving model to `{}`...'.format(model_save_path))
# --> 307             mu.save_model(model=s2s_model, path=model_save_path)
#     308             log.info('Saved model to `{}`.'.format(model_save_path))
#     309     return epoch_stats_list
#
# /indocker/src/model_utils.py in save_model(model, path)
#     171 def save_model(model, path):
#     172     with open(path, 'wb') as outfile:
# --> 173         pickle.dump(model, outfile, pickle.HIGHEST_PROTOCOL)
#     174
#     175
#
# PicklingError: Can't pickle <class 's2s_autoencoder.Seq2SeqAutoEncoder'>: it's not the same object as s2s_autoencoder.Seq2SeqAutoEncoder

# %%
for d in dataloader:
    break

# %%
s2s_ae.forward(batch_sent_ixs=d['train']).dec_fwd.output_sents
# Out:
# [['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ['<SOS>', '<EOS>'],
#  ...]

# %%
encd = s2s_ae.encode_sentences(
    sents=train_tkns,
)
# Out:
# 2018-03-17 02:12:35,197:model_utils:INFO: Had to truncate `2` sentences

# %%
x = s2s_ae.decode_sentences(enc_hiddens=encd)

# %%
x
# Out:
# [['<SOS>', '<EOS>'], ['<SOS>', '<EOS>']]

# %%
cudable_variable(
    tc.LongTensor([[1,2,3,5], [23,3,54,5]]),
    requires_grad=False,
)
